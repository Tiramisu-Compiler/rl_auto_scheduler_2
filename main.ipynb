# %%
from env_api.core.services.converting_service import *

# %%
program_annotation= {
        "memory_size": "3.027374267578125",
        "iterators": {
            "i0": {
                "lower_bound": "1",
                "upper_bound": "257",
                "parent_iterator": None,
                "child_iterators": [
                    "i1"
                ],
                "computations_list": []
            },
            "i1": {
                "lower_bound": "1",
                "upper_bound": "1537",
                "parent_iterator": "i0",
                "child_iterators": [
                    "i2"
                ],
                "computations_list": []
            },
            "i2": {
                "lower_bound": "0",
                "upper_bound": "1280",
                "parent_iterator": "i1",
                "child_iterators": [],
                "computations_list": [
                    "comp00"
                ]
            }
        },
        "computations": {
            "comp00": {
                "absolute_order": 1,
                "iterators": [
                    "i0",
                    "i1",
                    "i2"
                ],
                "comp_is_reduction": True,
                "number_of_additions": 7,
                "number_of_subtraction": 0,
                "number_of_multiplication": 1,
                "number_of_division": 0,
                "write_access_relation": "{ comp00[i0, i1, i2] -> buf00[i0, i1] }",
                "write_buffer_id": 0,
                "data_type": "float64",
                "data_type_size": 0,
                "accesses": [
                    {
                        "access_is_reduction": True,
                        "buffer_id": 0,
                        "access_matrix": [
                            [
                                1,
                                0,
                                0,
                                0
                            ],
                            [
                                0,
                                1,
                                0,
                                0
                            ]
                        ]
                    },
                    {
                        "access_is_reduction": True,
                        "buffer_id": 0,
                        "access_matrix": [
                            [
                                1,
                                0,
                                0,
                                0
                            ],
                            [
                                0,
                                1,
                                0,
                                -1
                            ]
                        ]
                    },
                    {
                        "access_is_reduction": True,
                        "buffer_id": 0,
                        "access_matrix": [
                            [
                                1,
                                0,
                                0,
                                0
                            ],
                            [
                                0,
                                1,
                                0,
                                1
                            ]
                        ]
                    },
                    {
                        "access_is_reduction": True,
                        "buffer_id": 0,
                        "access_matrix": [
                            [
                                1,
                                0,
                                0,
                                -1
                            ],
                            [
                                0,
                                1,
                                0,
                                0
                            ]
                        ]
                    },
                    {
                        "access_is_reduction": True,
                        "buffer_id": 0,
                        "access_matrix": [
                            [
                                1,
                                0,
                                0,
                                1
                            ],
                            [
                                0,
                                1,
                                0,
                                -1
                            ]
                        ]
                    },
                    {
                        "access_is_reduction": True,
                        "buffer_id": 0,
                        "access_matrix": [
                            [
                                1,
                                0,
                                0,
                                -1
                            ],
                            [
                                0,
                                1,
                                0,
                                -1
                            ]
                        ]
                    },
                    {
                        "access_is_reduction": True,
                        "buffer_id": 0,
                        "access_matrix": [
                            [
                                1,
                                0,
                                0,
                                -1
                            ],
                            [
                                0,
                                1,
                                0,
                                1
                            ]
                        ]
                    },
                    {
                        "access_is_reduction": True,
                        "buffer_id": 0,
                        "access_matrix": [
                            [
                                1,
                                0,
                                0,
                                1
                            ],
                            [
                                0,
                                1,
                                0,
                                0
                            ]
                        ]
                    },
                    {
                        "access_is_reduction": True,
                        "buffer_id": 0,
                        "access_matrix": [
                            [
                                1,
                                0,
                                0,
                                1
                            ],
                            [
                                0,
                                1,
                                0,
                                1
                            ]
                        ]
                    }
                ],
                "expression_representation": {
                    "expr_type": "add",
                    "children": [
                        {
                            "expr_type": "add",
                            "children": [
                                {
                                    "expr_type": "add",
                                    "children": [
                                        {
                                            "expr_type": "add",
                                            "children": [
                                                {
                                                    "expr_type": "add",
                                                    "children": [
                                                        {
                                                            "expr_type": "add",
                                                            "children": [
                                                                {
                                                                    "expr_type": "add",
                                                                    "children": [
                                                                        {
                                                                            "expr_type": "access",
                                                                            "children": []
                                                                        },
                                                                        {
                                                                            "expr_type": "access",
                                                                            "children": []
                                                                        }
                                                                    ]
                                                                },
                                                                {
                                                                    "expr_type": "access",
                                                                    "children": []
                                                                }
                                                            ]
                                                        },
                                                        {
                                                            "expr_type": "mul",
                                                            "children": [
                                                                {
                                                                    "expr_type": "access",
                                                                    "children": []
                                                                },
                                                                {
                                                                    "expr_type": "access",
                                                                    "children": []
                                                                }
                                                            ]
                                                        }
                                                    ]
                                                },
                                                {
                                                    "expr_type": "access",
                                                    "children": []
                                                }
                                            ]
                                        },
                                        {
                                            "expr_type": "access",
                                            "children": []
                                        }
                                    ]
                                },
                                {
                                    "expr_type": "access",
                                    "children": []
                                }
                            ]
                        },
                        {
                            "expr_type": "access",
                            "children": []
                        }
                    ]
                }
            }
        }
    }

# %%
ConvertService.get_tree_structure(program_annotation)
# Out:
# {'loop_name': 'i0',
#  'computations_list': [],
#  'child_list': [{'loop_name': 'i1',
#    'computations_list': [],
#    'child_list': [{'loop_name': 'i2',
#      'computations_list': ['comp00'],
#      'child_list': []}]}]}

# %%
import pickle

# %%
with open("./" , "rb") as file :
    data = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 with open("/scratch/sk10691/workspace/rl/learn_from_dataset/rl_auto_scheduler/Dataset_pickle/full_legality_annotations_updated_1.pkl" , "rb") as file :
#       2     data = pickle.load(file)
#
# File /scratch/dl5133/conda-envs/tiramisu-build-env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: '/scratch/sk10691/workspace/rl/learn_from_dataset/rl_auto_scheduler/Dataset_pickle/full_legality_annotations_updated_1.pkl'

# %%
data['function605196']['schedule_l']
# Out:
# {'filename': './function605196_explored_schedules.json',
#  'node_name': 'lanka21',
#  'parameters': {'beam_size': 3, 'max_depth': 6},
#  'program_annotation': {'memory_size': '0.2734375',
#   'iterators': {'i0': {'lower_bound': 0,
#     'upper_bound': 32,
#     'parent_iterator': None,
#     'child_iterators': ['i1'],
#     'computations_list': []},
#    'i1': {'lower_bound': 0,
#     'upper_bound': 32,
#     'parent_iterator': 'i0',
#     'child_iterators': ['i2'],
#     'computations_list': []},
#    'i2': {'lower_bound': 0,
#     'upper_bound': 32,
#     'parent_iterator': 'i1',
#     'child_iterators': [],
#     'computations_list': ['comp00']}},
#   'computations': {'comp00': {'absolute_order': 1,
#     'iterators': ['i0', 'i1', 'i2'],
#     'comp_is_reduction': True,
#     'number_of_additions': 3,
#     'number_of_subtraction': 0,
#     'number_of_multiplication': 1,
#     'number_of_division': 0,
#     'write_access_relation': '{ comp00[i0, i1, i2] -> buf00[i0, i1] }',
#     'write_buffer_id': 0,
#     'data_type': 'float64',
#     'data_type_size': 0,
#     'accesses': [{'access_is_reduction': True,
#       'buffer_id': 0,
#       'access_matrix': [[1, 0, 0, 0], [0, 1, 0, 0]]},
#      {'access_is_reduction': False,
#       'buffer_id': 2,
#       'access_matrix': [[0, 1, 0, 0], [0, 0, 1, 0]]},
#      {'access_is_reduction': False,
#       'buffer_id': 1,
#       'access_matrix': [[1, 0, 0, 1], [0, 1, 0, 0], [0, 0, 1, 0]]}]}}},
#  'initial_execution_time': 0.076018,
#  'schedules_list': [{'comp00': {'interchange_dims': [],
#     'tiling': {},
#     'unrolling_factor': None,
#     'parallelized_dim': None,
#     'skewing': None},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [0.129338,
#     0.113261,
#     0.112698,
#     0.11301,
#     0.112252,
#     0.112372,
#     0.112,
#     0.111955,
#     0.111905,
#     0.111981,
#     0.112034,
#     0.112913,
#     0.111943,
#     0.11191,
#     0.111972,
#     0.111991,
#     0.123437,
#     0.07667,
#     0.076018,
#     0.094592,
#     0.116716,
#     0.111911,
#     0.112103,
#     0.112008,
#     0.111949,
#     0.112014,
#     0.112084,
#     0.11193,
#     0.112079,
#     0.112061]},
#   {'comp00': {'interchange_dims': ['i0', 'i2'],
#     'tiling': {},
#     'unrolling_factor': None,
#     'parallelized_dim': None,
#     'skewing': None},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [0.099235,
#     0.07713,
#     0.075621,
#     0.076423,
#     0.076355,
#     0.07587,
#     0.075452,
#     0.075295,
#     0.0752,
#     0.075199,
#     0.07504,
#     0.075125,
#     0.075108,
#     0.075158,
#     0.074948,
#     0.075318,
#     0.074893,
#     0.07509,
#     0.075255,
#     0.075129,
#     0.075313,
#     0.074862,
#     0.07527,
#     0.075373,
#     0.07478,
#     0.07536,
#     0.075628,
#     0.07518,
#     0.074824,
#     0.075035]},
#   {'comp00': {'interchange_dims': ['i1', 'i2'],
#     'tiling': {},
#     'unrolling_factor': None,
#     'parallelized_dim': None,
#     'skewing': None},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [0
},
#   {'comp00': {'interchange_dims': ['i1', 'i2'],
#     'tiling': {},
#     'unrolling_factor': '16',
#     'parallelized_dim': 'i2',
#     'skewing': {'skewed_dims': ['i0', 'i2'],
#      'skewing_factors': [1, 1],
#      'average_skewed_extents': [62, 16],
#      'transformed_accesses': [{'buffer_id': 0,
#        'access_matrix': [[1, 0, 0, 0], [0, 1, 0, 0]]},
#       {'buffer_id': 2, 'access_matrix': [[0, 1, 0, 0], [0, 0, 1, 0]]},
#       {'buffer_id': 1,
#        'access_matrix': [[1, 0, 0, 1], [0, 1, 0, 0], [0, 0, 1, 0]]}]}},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [8.24033,
#     7.17155,
#     6.93883,
#     6.56143,
#     6.96625,
#     7.55357,
#     7.23405,
#     7.20458,
#     6.75721,
#     6.74704,
#     7.15908,
#     7.00186,
#     7.25962,
#     7.57138,
#     7.65407,
#     7.48606,
#     7.44343,
#     6.73288,
#     7.06673,
#     6.97604,
#     7.55296,
#     6.88992,
#     7.20947,
#     7.10391,
#     6.95602,
#     7.24387,
#     6.78409,
#     7.01064,
#     7.24756,
#     7.67206]},
#   {'comp00': {'interchange_dims': ['i1', 'i2'],
#     'tiling': {},
#     'unrolling_factor': '4',
#     'parallelized_dim': 'i1',
#     'skewing': {'skewed_dims': ['i0', 'i2'],
#      'skewing_factors': [1, 1],
#      'average_skewed_extents': [62, 16],
#      'transformed_accesses': [{'buffer_id': 0,
#        'access_matrix': [[1, 0, 0, 0], [0, 1, 0, 0]]},
#       {'buffer_id': 2, 'access_matrix': [[0, 1, 0, 0], [0, 0, 1, 0]]},
#       {'buffer_id': 1,
#        'access_matrix': [[1, 0, 0, 1], [0, 1, 0, 0], [0, 0, 1, 0]]}]}},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [27.5961,
#     27.223301,
#     27.2479,
#     27.632099,
#     27.655399,
#     27.2889,
#     27.0811,
#     25.181101,
#     25.614,
#     25.365101,
#     25.4212,
#     25.5331,
#     25.2451,
#     24.440701,
#     24.695,
#     24.6423,
#     24.749701,
#     24.587601,
#     24.867901,
#     24.824499,
#     24.144899,
#     24.931,
#     24.541901,
#     24.998699,
#     24.1646,
#     24.5161,
#     24.468201,
#     24.756201,
#     24.909,
#     24.5744]},
#   {'comp00': {'interchange_dims': ['i1', 'i2'],
#     'tiling': {},
#     'unrolling_factor': '8',
#     'parallelized_dim': 'i1',
#     'skewing': {'skewed_dims': ['i0', 'i2'],
#      'skewing_factors': [1, 1],
#      'average_skewed_extents': [62, 16],
#      'transformed_accesses': [{'buffer_id': 0,
#        'access_matrix': [[1, 0, 0, 0], [0, 1, 0, 0]]},
#       {'buffer_id': 2, 'access_matrix': [[0, 1, 0, 0], [0, 0, 1, 0]]},
#       {'buffer_id': 1,
#        'access_matrix': [[1, 0, 0, 1], [0, 1, 0, 0], [0, 0, 1, 0]]}]}},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [15.2758,
#     10.6813,
#     10.1186,
#     9.71124,
#     9.88077,
#     10.2251,
#     9.65213,
#     9.8697,
#     10.0715,
#     9.73179,
#     9.77082,
#     9.86102,
#     9.62397,
#     9.70968,
#     9.76855,
#     9.87867,
#     9.54496,
#     9.90999,
#     9.90604,
#     9.79066,
#     9.89385,
#     10.128,
#     10.2324,
#     9.88674,
#     9.70555,
#     9.80596,
#     9.61328,
#     9.76109,
#     9.92163,
#     9.83375]},
#   {'comp00': {'interchange_dims': ['i1', 'i2'],
#     'tiling': {},
#     'unrolling_factor': '16',
#     'parallelized_dim': 'i1',
#     'skewing': {'skewed_dims': ['i0', 'i2'],
#      'skewing_factors': [1, 1],
#      'average_skewed_extents': [62, 16],
#      'transformed_accesses': [{'buffer_id': 0,
#        'access_matrix': [[1, 0, 0, 0], [0, 1, 0, 0]]},
#       {'buffer_id': 2, 'access_matrix': [[0, 1, 0, 0], [0, 0, 1, 0]]},
#       {'buffer_id': 1,
#        'access_matrix': [[1, 0, 0, 1], [0, 1, 0, 0], [0, 0, 1, 0]]}]}},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [4.66003,
#     1.31038,
#     1.3119,
#     1.3885,
#     1.3742,
#     1.26526,
#     0.96289,
#     0.951772,
#     0.938967,
#     0.96226,
#     0.97865,
#     1.00832,
#     0.980175,
#     0.925018,
#     0.984189,
#     0.942703,
#     0.891796,
#     0.903548,
#     0.922164,
#     0.922716,
#     0.932247,
#     0.936928,
#     0.915838,
#     0.976006,
#     0.906028,
#     0.953785,
#     0.931211,
#     1.01951,
#     1.01331,
#     1.04378]},
#   {'comp00': {'interchange_dims': ['i0', 'i2'],
#     'tiling': {},
#     'unrolling_factor': None,
#     'parallelized_dim': 'i1',
#     'skewing': None},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [5.35861,
#     3.58144,
#     3.81449,
#     4.06578,
#     3.88763,
#     4.03583,
#     3.87334,
#     3.93776,
#     3.84718,
#     3.79983,
#     3.77848,
#     3.78156,
#     3.92007,
#     3.86102,
#     3.80102,
#     3.89761,
#     3.8382,
#     3.84391,
#     3.90157,
#     3.79816,
#     3.70842,
#     3.84681,
#     3.92158,
#     3.86373,
#     3.87694,
#     3.83009,
#     3.69548,
#     3.86996,
#     3.84212,
#     3.80259]},
#   {'comp00': {'interchange_dims': ['i0', 'i2'],
#     'tiling': {},
#     'unrolling_factor': None,
#     'parallelized_dim': 'i0',
#     'skewing': None},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [116.268997,
#     115.991997,
#     116.611,
#     115.869003,
#     115.492996,
#     116.382004,
#     117.953003,
#     119.098,
#     119.146004,
#     118.750999,
#     119.511002,
#     119.920998,
#     119.170998,
#     118.598999,
#     119.751999,
#     120.098999,
#     119.317001,
#     118.959,
#     119.129997,
#     119.675003,
#     119.382004,
#     119.213997,
#     118.538002,
#     119.977997,
#     119.276001,
#     120.376999,
#     119.416,
#     118.626999,
#     118.642998,
#     119.698997]},
#   {'comp00': {'interchange_dims': ['i0', 'i2'],
#     'tiling': {},
#     'unrolling_factor': '4',
#     'parallelized_dim': None,
#     'skewing': None},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [0.079741,
#     0.061927,
#     0.060854,
#     0.061043,
#     0.061047,
#     0.060314,
#     0.060638,
#     0.060261,
#     0.06011,
#     0.06009,
#     0.059997,
#     0.059995,
#     0.060285,
#     0.060018,
#     0.060239,
#     0.060023,
#     0.060143,
#     0.059972,
#     0.059937,
#     0.06032,
#     0.060275,
#     0.059851,
#     0.060411,
#     0.08535,
#     0.065156,
#     0.064611,
#     0.06474,
#     0.077681,
#     0.060357,
#     0.059987]},
#   {'comp00': {'interchange_dims': ['i0', 'i2'],
#     'tiling': {},
#     'unrolling_factor': '8',
#     'parallelized_dim': None,
#     'skewing': None},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [0.096047,
#     0.068867,
#     0.067541,
#     0.068295,
#     0.068331,
#     0.067634,
#     0.067929,
#     0.067013,
#     0.067127,
#     0.067268,
#     0.067165,
#     0.067383,
#     0.066871,
#     0.067421,
#     0.067122,
#     0.06696,
#     0.067141,
#     0.067168,
#     0.067181,
#     0.067262,
#     0.067117,
#     0.067088,
#     0.067156,
#     0.067034,
#     0.067356,
#     0.067201,
#     0.067061,
#     0.067151,
#     0.067114,
#     0.067049]},
#   {'comp00': {'interchange_dims': ['i0', 'i2'],
#     'tiling': {},
#     'unrolling_factor': '16',
#     'parallelized_dim': None,
#     'skewing': None},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [0.093068,
#     0.076945,
#     0.07545,
#     0.076445,
#     0.076271,
#     0.075589,
#     0.075953,
#     0.075362,
#     0.07538,
#     0.075483,
#     0.075636,
#     0.075485,
#     0.075015,
#     0.07553,
#     0.075255,
#     0.075654,
#     0.074988,
#     0.075423,
#     0.075267,
#     0.074975,
#     0.075033,
#     0.075305,
#     0.075013,
#     0.07499,
#     0.07529,
#     0.075737,
#     0.075293,
#     0.075055,
#     0.075183,
#     0.07525]},
#   {'comp00': {'interchange_dims': ['i0', 'i2'],
#     'tiling': {},
#     'unrolling_factor': '4',
#     'parallelized_dim': 'i1',
#     'skewing': None},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [6.85204,
#     4.177,
#     3.88842,
#     4.07377,
#     3.95673,
#     4.05958,
# ...
#     0.108285,
#     0.114522,
#     0.107583,
#     0.100572,
#     0.108899,
#     0.107277,
#     0.106971,
#     0.109434,
#     0.111093,
#     0.106247,
#     0.110528,
#     0.104426,
#     0.108176,
#     0.106161,
#     0.0968,
#     0.11179,
#     0.113863,
#     0.098894,
#     0.10147,
#     0.109452,
#     0.111025,
#     0.105049,
#     0.103145]},
#   {'comp00': {'interchange_dims': [],
#     'tiling': {},
#     'unrolling_factor': '4',
#     'parallelized_dim': 'i1',
#     'skewing': None},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [6.25358,
#     4.16577,
#     4.24229,
#     3.7659,
#     3.50798,
#     3.50262,
#     3.5728,
#     3.59974,
#     3.31094,
#     3.327,
#     3.37891,
#     3.48614,
#     3.78289,
#     3.73243,
#     3.67814,
#     3.69362,
#     3.58655,
#     3.72673,
#     3.67134,
#     3.79348,
#     3.75476,
#     3.65645,
#     3.68091,
#     3.54987,
#     3.71007,
#     3.68911,
#     3.71448,
#     3.68958,
#     3.80469,
#     3.77966]},
#   {'comp00': {'interchange_dims': [],
#     'tiling': {},
#     'unrolling_factor': '8',
#     'parallelized_dim': 'i1',
#     'skewing': None},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [5.93315,
#     3.77352,
#     3.84539,
#     4.07134,
#     4.10585,
#     4.11389,
#     4.12364,
#     4.09935,
#     3.99194,
#     4.02966,
#     4.07561,
#     4.08678,
#     3.96577,
#     3.8266,
#     3.92168,
#     3.87658,
#     3.77415,
#     3.95883,
#     3.7712,
#     3.90232,
#     4.00979,
#     3.77822,
#     3.8064,
#     3.82215,
#     4.02406,
#     3.94495,
#     3.93925,
#     3.84826,
#     3.81598,
#     3.83973]},
#   {'comp00': {'interchange_dims': [],
#     'tiling': {},
#     'unrolling_factor': '16',
#     'parallelized_dim': 'i1',
#     'skewing': None},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [5.77092,
#     4.16668,
#     4.847,
#     4.23989,
#     4.23694,
#     4.29355,
#     4.22428,
#     4.17963,
#     4.13778,
#     4.18614,
#     4.15281,
#     4.1719,
#     4.13327,
#     4.18356,
#     4.04982,
#     3.90039,
#     4.04566,
#     3.98563,
#     4.00634,
#     3.88093,
#     3.92235,
#     3.94889,
#     4.07136,
#     3.94351,
#     4.04054,
#     3.90082,
#     3.95078,
#     3.83201,
#     4.04232,
#     4.04331]},
#   {'comp00': {'interchange_dims': [],
#     'tiling': {},
#     'unrolling_factor': None,
#     'parallelized_dim': 'i0',
#     'skewing': {'skewed_dims': ['i1', 'i2'],
#      'skewing_factors': [1, 2],
#      'average_skewed_extents': [93, 11],
#      'transformed_accesses': [{'buffer_id': 0,
#        'access_matrix': [[1, 0, 0, 0], [0, 1, 0, 0]]},
#       {'buffer_id': 2, 'access_matrix': [[0, 1, 0, 0], [0, 0, 1, 0]]},
#       {'buffer_id': 1,
#        'access_matrix': [[1, 0, 0, 1], [0, 1, 0, 0], [0, 0, 1, 0]]}]}},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [1.59198,
#     0.156968,
#     0.13483,
#     0.147567,
#     0.147051,
#     0.143435,
#     0.132061,
#     0.128384,
#     0.142214,
#     0.137659,
#     0.146975,
#     0.134662,
#     0.13132,
#     0.146875,
#     0.146002,
#     0.136993,
#     0.130774,
#     0.126297,
#     0.135631,
#     0.166718,
#     0.163289,
#     0.152208,
#     0.152265,
#     0.152373,
#     0.149388,
#     0.155345,
#     0.148595,
#     0.149841,
#     0.157512,
#     0.146574]},
#   {'comp00': {'interchange_dims': [],
#     'tiling': {},
#     'unrolling_factor': None,
#     'parallelized_dim': 'i2',
#     'skewing': {'skewed_dims': ['i1', 'i2'],
#      'skewing_factors': [1, 2],
#      'average_skewed_extents': [93, 11],
#      'transformed_accesses': [{'buffer_id': 0,
#        'access_matrix': [[1, 0, 0, 0], [0, 1, 0, 0]]},
#       {'buffer_id': 2, 'access_matrix': [[0, 1, 0, 0], [0, 0, 1, 0]]},
#       {'buffer_id': 1,
#        'access_matrix': [[1, 0, 0, 1], [0, 1, 0, 0], [0, 0, 1, 0]]}]}},
#    'unfuse_iterators': [],
#    'tree_structure': {'loop_name': 'i0',
#     'computations_list': [],
#     'child_list': [{'loop_name': 'i1',
#       'computations_list': [],
#       'child_list': [{'loop_name': 'i2',
#         'computations_list': ['comp00'],
#         'child_list': []}]}]},
#    'execution_times': [166.772003,
#     164.460999,
#     163.518997,
#     163.048996,
#     171.203995,
#     170.475006,
#     163.903,
#     163.194,
#     166.742004,
#     167.352997,
#     162.589005,
#     164.681,
#     166.574997,
#     163.130997,
#     164.419006,
#     167.983002,
#     167.800995,
#     169.5,
#     167.095001,
#     169.104996,
#     163.315994,
#     165.813004,
#     163.975998,
#     163.572998,
#     165.417007,
#     161.516998,
#     165.947998,
#     166.311996,
#     165.953003,
#     175.294006]}],
#  'exploration_trace': {'id': 0,
#   'schedule': '',
#   'depth': 1,
#   'evaluation': 0.076018,
#   'children': [{'id': 1,
#     'schedule': 'I(L0,L1)',
#     'depth': 1,
#     'evaluation': 0.09134,
#     'children': []},
#    {'id': 2,
#     'schedule': 'I(L0,L2)',
#     'depth': 1,
#     'evaluation': 0.07478,
#     'children': [{'id': 40,
#       'schedule': 'I(L0,L2)P(L1)',
#       'depth': 2,
#       'evaluation': 3.58144,
#       'children': [{'id': 45,
#         'schedule': 'I(L0,L2)P(L1)U(L2,4)',
#         'depth': 3,
#         'evaluation': 3.73733,
#         'children': []},
#        {'id': 46,
#         'schedule': 'I(L0,L2)P(L1)U(L2,8)',
#         'depth': 3,
#         'evaluation': 3.85855,
#         'children': []},
#        {'id': 47,
#         'schedule': 'I(L0,L2)P(L1)U(L2,16)',
#         'depth': 3,
#         'evaluation': 3.68363,
#         'children': []}]},
#      {'id': 41,
#       'schedule': 'I(L0,L2)P(L2)',
#       'depth': 2,
#       'evaluation': 115.492996,
#       'children': [{'id': 48,
#         'schedule': 'I(L0,L2)P(L2)U(L2,4)',
#         'depth': 3,
#         'evaluation': 23.866301,
#         'children': []},
#        {'id': 49,
#         'schedule': 'I(L0,L2)P(L2)U(L2,8)',
#         'depth': 3,
#         'evaluation': 6.08661,
#         'children': []},
#        {'id': 50,
#         'schedule': 'I(L0,L2)P(L2)U(L2,16)',
#         'depth': 3,
#         'evaluation': 0.675946,
#         'children': []}]},
#      {'id': 2,
#       'schedule': 'I(L0,L2)',
#       'depth': 2,
#       'evaluation': 0.07478,
#       'children': [{'id': 42,
#         'schedule': 'I(L0,L2)U(L2,4)',
#         'depth': 3,
#         'evaluation': 0.059851,
#         'children': []},
#        {'id': 43,
#         'schedule': 'I(L0,L2)U(L2,8)',
#         'depth': 3,
#         'evaluation': 0.066871,
#         'children': []},
#        {'id': 44,
#         'schedule': 'I(L0,L2)U(L2,16)',
#         'depth': 3,
#         'evaluation': 0.074975,
#         'children': []}]}]},
#    {'id': 3,
#     'schedule': 'I(L1,L2)',
#     'depth': 1,
#     'evaluation': 0.057529,
#     'children': [{'id': 4,
#       'schedule': 'I(L1,L2)S(L0,L1,1,1)',
#       'depth': 2,
#       'evaluation': 0.068045,
#       'children': [{'id': 29,
#         'schedule': 'I(L1,L2)S(L0,L1,1,1)P(L1)',
#         'depth': 3,
#         'evaluation': 6.54438,
#         'children': [{'id': 34,
#           'schedule': 'I(L1,L2)S(L0,L1,1,1)P(L1)U(L2,4)',
#           'depth': 4,
#           'evaluation': 5.57151,
#           'children': []},
#          {'id': 35,
#           'schedule': 'I(L1,L2)S(L0,L1,1,1)P(L1)U(L2,8)',
#           'depth': 4,
#           'evaluation': 6.64841,
#           'children': []},
#          {'id': 36,
#           'schedule': 'I(L1,L2)S(L0,L1,1,1)P(L1)U(L2,16)',
#           'depth': 4,
#           'evaluation': 6.56143,
#           'children': []}]},
#        {'id': 30,
#         'schedule': 'I(L1,L2)S(L0,L1,1,1)P(L2)',
#         'depth': 3,
#         'evaluation': 106.815002,
#         'children': [{'id': 37,
#           'schedule': 'I(L1,L2)S(L0,L1,1,1)P(L2)U(L2,4)',
#           'depth': 4,
#           'evaluation': 24.144899,
#           'children': []},
#          {'id': 38,
#           'schedule': 'I(L1,L2)S(L0,L1,1,1)P(L2)U(L2,8)',
#           'depth': 4,
#           'evaluation': 9.54496,
#           'children': []},
#          {'id': 39,
#           'schedule': 'I(L1,L2)S(L0,L1,1,1)P(L2)U(L2,16)',
#           'depth': 4,
#           'evaluation': 0.891796,
#           'children': []}]},
#        {'id': 4,
#         'schedule': 'I(L1,L2)S(L0,L1,1,1)',
#         'depth': 3,
#         'evaluation': 0.068045,
#         'children': [{'id': 31,
#           'schedule': 'I(L1,L2)S(L0,L1,1,1)U(L2,4)',
#           'depth': 4,
#           'evaluation': 0.050512,
#           'children': []},
#          {'id': 32,
#           'schedule': 'I(L1,L2)S(L0,L1,1,1)U(L2,8)',
#           'depth': 4,
#           'evaluation': 0.115055,
#           'children': []},
#          {'id': 33,
#           'schedule': 'I(L1,L2)S(L0,L1,1,1)U(L2,16)',
#           'depth': 4,
#           'evaluation': 0.062357,
#           'children': []}]}]},
#      {'id': 5,
#       'schedule': 'I(L1,L2)S(L0,L1,1,2)',
#       'depth': 2,
#       'evaluation': 0.053763,
#       'children': [{'id': 7,
#         'schedule': 'I(L1,L2)S(L0,L1,1,2)P(L1)',
#         'depth': 3,
#         'evaluation': 5.51231,
#         'children': [{'id': 12,
#           'schedule': 'I(L1,L2)S(L0,L1,1,2)P(L1)U(L2,4)',
#           'depth': 4,
#           'evaluation': 5.25852,
#           'children': []},
#          {'id': 13,
#           'schedule': 'I(L1,L2)S(L0,L1,1,2)P(L1)U(L2,8)',
#           'depth': 4,
#           'evaluation': 5.13029,
#           'children': []},
#          {'id': 14,
#           'schedule': 'I(L1,L2)S(L0,L1,1,2)P(L1)U(L2,16)',
#           'depth': 4,
#           'evaluation': 5.38413,
#           'children': []}]},
#        {'id': 8,
#         'schedule': 'I(L1,L2)S(L0,L1,1,2)P(L2)',
#         'depth': 3,
#         'evaluation': 93.7771,
#         'children': [{'id': 15,
#           'schedule': 'I(L1,L2)S(L0,L1,1,2)P(L2)U(L2,4)',
#           'depth': 4,
#           'evaluation': 25.111,
#           'children': []},
#          {'id': 16,
#           'schedule': 'I(L1,L2)S(L0,L1,1,2)P(L2)U(L2,8)',
#           'depth': 4,
#           'evaluation': 6.75591,
#           'children': []},
#          {'id': 17,
#           'schedule': 'I(L1,L2)S(L0,L1,1,2)P(L2)U(L2,16)',
#           'depth': 4,
#           'evaluation': 0.96833,
#           'children': []}]},
#        {'id': 5,
#         'schedule': 'I(L1,L2)S(L0,L1,1,2)',
#         'depth': 3,
#         'evaluation': 0.053763,
#         'children': [{'id': 9,
#           'schedule': 'I(L1,L2)S(L0,L1,1,2)U(L2,4)',
#           'depth': 4,
#           'evaluation': 0.062286,
#           'children': []},
#          {'id': 10,
#           'schedule': 'I(L1,L2)S(L0,L1,1,2)U(L2,8)',
#           'depth': 4,
#           'evaluation': 0.062949,
#           'children': []},
#          {'id': 11,
#           'schedule': 'I(L1,L2)S(L0,L1,1,2)U(L2,16)',
#           'depth': 4,
#           'evaluation': 0.05011,
#           'children': []}]}]},
#      {'id': 6,
#       'schedule': 'I(L1,L2)S(L0,L1,1,3)',
#       'depth': 2,
#       'evaluation': 0.07202,
#       'children': []},
#      {'id': 3,
#       'schedule': 'I(L1,L2)',
#       'depth': 2,
#       'evaluation': 0.057529,
#       'children': [{'id': 18,
#         'schedule': 'I(L1,L2)P(L0)',
#         'depth': 3,
#         'evaluation': 0.10919,
#         'children': [{'id': 23,
#           'schedule': 'I(L1,L2)P(L0)U(L2,4)',
#           'depth': 4,
#           'evaluation': 0.115182,
#           'children': []},
#          {'id': 24,
#           'schedule': 'I(L1,L2)P(L0)U(L2,8)',
#           'depth': 4,
#           'evaluation': 0.109756,
#           'children': []},
#          {'id': 25,
#           'schedule': 'I(L1,L2)P(L0)U(L2,16)',
#           'depth': 4,
#           'evaluation': 0.114365,
#           'children': []}]},
#        {'id': 19,
#         'schedule': 'I(L1,L2)P(L2)',
#         'depth': 3,
#         'evaluation': 94.7015,
#         'children': [{'id': 26,
#           'schedule': 'I(L1,L2)P(L2)U(L2,4)',
#           'depth': 4,
#           'evaluation': 26.440599,
#           'children': []},
#          {'id': 27,
#           'schedule': 'I(L1,L2)P(L2)U(L2,8)',
#           'depth': 4,
#           'evaluation': 5.52684,
#           'children': []},
#          {'id': 28,
#           'schedule': 'I(L1,L2)P(L2)U(L2,16)',
#           'depth': 4,
#           'evaluation': 0.586492,
#           'children': []}]},
#        {'id': 3,
#         'schedule': 'I(L1,L2)',
#         'depth': 3,
#         'evaluation': 0.057529,
#         'children': [{'id': 20,
#           'schedule': 'I(L1,L2)U(L2,4)',
#           'depth': 4,
#           'evaluation': 0.031199,
#           'children': []},
#          {'id': 21,
#           'schedule': 'I(L1,L2)U(L2,8)',
#           'depth': 4,
#           'evaluation': 0.026847,
#           'children': []},
#          {'id': 22,
#           'schedule': 'I(L1,L2)U(L2,16)',
#           'depth': 4,
#           'evaluation': 0.04137,
#           'children': []}]}]}]},
#    {'id': 0,
#     'schedule': '',
#     'depth': 1,
#     'evaluation': 0.076018,
#     'children': [{'id': 51,
#       'schedule': 'S(L1,L2,1,1)',
#       'depth': 2,
#       'evaluation': 0.063405,
#       'children': [{'id': 54,
#         'schedule': 'S(L1,L2,1,1)P(L0)',
#         'depth': 3,
#         'evaluation': 0.125499,
#         'children': []},
#        {'id': 55,
#         'schedule': 'S(L1,L2,1,1)P(L2)',
#         'depth': 3,
#         'evaluation': 195.630997,
#         'children': []},
#        {'id': 51,
#         'schedule': 'S(L1,L2,1,1)',
#         'depth': 3,
#         'evaluation': 0.063405,
#         'children': []}]},
#      {'id': 52,
#       'schedule': 'S(L1,L2,1,2)',
#       'depth': 2,
#       'evaluation': 0.081169,
#       'children': [{'id': 67,
#         'schedule': 'S(L1,L2,1,2)P(L0)',
#         'depth': 3,
#         'evaluation': 0.126297,
#         'children': []},
#        {'id': 68,
#         'schedule': 'S(L1,L2,1,2)P(L2)',
#         'depth': 3,
#         'evaluation': 161.516998,
#         'children': []},
#        {'id': 52,
#         'schedule': 'S(L1,L2,1,2)',
#         'depth': 3,
#         'evaluation': 0.081169,
#         'children': []}]},
#      {'id': 53,
#       'schedule': 'S(L1,L2,1,3)',
#       'depth': 2,
#       'evaluation': 0.095868,
#       'children': []},
#      {'id': 0,
#       'schedule': '',
#       'depth': 2,
#       'evaluation': 0.076018,
#       'children': [{'id': 56,
#         'schedule': 'P(L0)',
#         'depth': 3,
#         'evaluation': 0.105469,
#         'children': [{'id': 61,
#           'schedule': 'P(L0)U(L2,4)',
#           'depth': 4,
#           'evaluation': 0.115492,
#           'children': []},
#          {'id': 62,
#           'schedule': 'P(L0)U(L2,8)',
#           'depth': 4,
#           'evaluation': 0.114529,
#           'children': []},
#          {'id': 63,
#           'schedule': 'P(L0)U(L2,16)',
#           'depth': 4,
#           'evaluation': 0.0968,
#           'children': []}]},
#        {'id': 57,
#         'schedule': 'P(L1)',
#         'depth': 3,
#         'evaluation': 3.56948,
#         'children': [{'id': 64,
#           'schedule': 'P(L1)U(L2,4)',
#           'depth': 4,
#           'evaluation': 3.31094,
#           'children': []},
#          {'id': 65,
#           'schedule': 'P(L1)U(L2,8)',
#           'depth': 4,
#           'evaluation': 3.7712,
#           'children': []},
#          {'id': 66,
#           'schedule': 'P(L1)U(L2,16)',
#           'depth': 4,
#           'evaluation': 3.83201,
#           'children': []}]},
#        {'id': 0,
#         'schedule': '',
#         'depth': 3,
#         'evaluation': 0.076018,
#         'children': [{'id': 58,
#           'schedule': 'U(L2,4)',
#           'depth': 4,
#           'evaluation': 0.088645,
#           'children': []},
#          {'id': 59,
#           'schedule': 'U(L2,8)',
#           'depth': 4,
#           'evaluation': 0.071061,
#           'children': []},
#          {'id': 60,
#           'schedule': 'U(L2,16)',
#           'depth': 4,
#           'evaluation': 0.072778,
#           'children': []}]}]}]}]}}
